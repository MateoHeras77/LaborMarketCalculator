# %%
import pandas as pd
import pyreadstat

# %%
pd.set_option('display.max_rows', None)

# %%
base=pd.read_spss(r"C:\Users\wmate\Downloads\SPSS\Compilado\2023.sav")

# %%
df=base.copy()
df.head()
# Out:
#    REC_NUM  SURVYEAR SURVMNTH                     LFSSTAT              PROV  \
# 0      1.0    2023.0    April           Employed, at work           Ontario
# 1      2.0    2023.0    April           Employed, at work       Nova Scotia
# 2      3.0    2023.0    April           Employed, at work           Alberta
# 3      4.0    2023.0    April         Not in labour force  British Columbia
# 4      5.0    2023.0    April  Employed, absent from work      Saskatchewan
#
#                     CMA          AGE_12           AGE_6     SEX  \
# 0               Toronto  50 to 54 years             NaN    Male
# 1  Other CMA or non-CMA  55 to 59 years             NaN  Female
# 2  Other CMA or non-CMA  55 to 59 years             NaN  Female
# 3  Other CMA or non-CMA  15 to 19 years  15 to 16 years    Male
# 4  Other CMA or non-CMA  25 to 29 years  27 to 29 years  Female
#
#                  MARSTAT  ... LKATADS LKANSADS LKOTHERN PRIORACT YNOLOOK  \
# ...

# %%
print(df["SURVYEAR"].unique())
print(df["SURVMNTH"].unique())
# Out:
# [2023.]
# ['April', 'August', 'December', 'February', 'January', ..., 'March', 'May', 'November', 'October', 'September']
# Length: 12
# Categories (12, object): ['April', 'August', 'December', 'February', ..., 'May', 'November', 'October', 'September']

# %%
df.dtypes

# %%
Y= df[["LFSSTAT"]]
X=df[["EDUC","AGE_12","IMMIG","HRLYEARN","TENURE","SEX","PROV","NAICS_21","FTPTMAIN","MARSTAT","DURUNEMP"]]

# %%
Y.head()
# Out:
#                LFSSTAT
# 0  Not in labour force
# 1    Employed, at work
# 2  Not in labour force
# 3    Employed, at work
# 4    Employed, at work

# %%
X.head()
# Out:
#                                    EDUC          AGE_12  \
# 0  Postsecondary certificate or diploma  65 to 69 years
# 1  Postsecondary certificate or diploma  40 to 44 years
# 2                  High school graduate     70 and over
# 3                    Some postsecondary  65 to 69 years
# 4  Postsecondary certificate or diploma     70 and over
#
#                                           IMMIG  HRLYEARN  TENURE     SEX  \
# 0                                 Non-immigrant       NaN     NaN    Male
# 1                                 Non-immigrant     17.25    12.0  Female
# 2                                 Non-immigrant       NaN     NaN  Female
# 3                                 Non-immigrant     31.73   240.0    Male
# 4  Immigrant, landed more than 10 years earlier     18.46    83.0  Female
#
#                PROV                                         NAICS_21  \
# 0          Manitoba                                              NaN
# ...

# %%
def calculate_zero_nan_percentages(df):
    # Porcentaje de datos que son 0
    zero_percentage = (df == 0).mean() * 100
    # Porcentaje de datos que son NaN
    nan_percentage = df.isna().mean() * 100

    return zero_percentage, nan_percentage

# %%
zero_percentage, nan_percentage = calculate_zero_nan_percentages(df)

print("Porcentaje de 0 en cada columna:\n", zero_percentage)
print("Porcentaje de NaN en cada columna:\n", nan_percentage)
# Out:
# Porcentaje de 0 en cada columna:
#  REC_NUM      0.000000
# SURVYEAR     0.000000
# SURVMNTH     0.000000
# LFSSTAT      0.000000
# PROV         0.000000
# CMA          0.000000
# AGE_12       0.000000
# AGE_6        0.000000
# SEX          0.000000
# MARSTAT      0.000000
# EDUC         0.000000
# MJH          0.000000
# EVERWORK     0.000000
# FTPTLAST     0.000000
# COWMAIN      0.000000
# IMMIG        0.000000
# NAICS_21     0.000000
# NOC_10       0.000000
# NOC_43       0.000000
# YABSENT      0.000000
# WKSAWAY      0.000000
# PAYAWAY      0.000000
# UHRSMAIN     0.000000
# AHRSMAIN     5.559070
# FTPTMAIN     0.000000
# UTOTHRS      0.000000
# ATOTHRS      5.518134
# HRSAWAY     39.081683
# YAWAY        0.000000
# PAIDOT      41.922733
# UNPAIDOT    42.715498
# XTRAHRS     38.380727
# WHYPT        0.000000
# TENURE       0.000000
# PREVTEN      0.000000
# HRLYEARN     0.000000
# UNION        0.000000
# PERMTEMP     0.000000
# ESTSIZE      0.000000
# FIRMSIZE     0.000000
# ...

# %%
df.groupby('LFSSTAT')['HRLYEARN'].mean().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_14720\2956596758.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('LFSSTAT')['HRLYEARN'].mean().reset_index()
#                       LFSSTAT   HRLYEARN
# 0  Employed, absent from work  34.100958
# 1           Employed, at work  32.821519
# 2         Not in labour force        NaN
# 3                  Unemployed        NaN

# %%
df['LFSSTAT'].value_counts().reset_index()
# Out:
#                       LFSSTAT   count
# 0           Employed, at work  723583
# 1         Not in labour force  505009
# 2  Employed, absent from work   74409
# 3                  Unemployed   45444

# %%
df['LFSSTAT'].value_counts().reset_index()
# Out:
#                       LFSSTAT  count
# 0           Employed, at work  54232
# 1         Not in labour force  35774
# 2  Employed, absent from work   4562
# 3                  Unemployed   2954

# %%
df.groupby('LFSSTAT')['HRLYEARN'].sum().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_14720\1007189753.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('LFSSTAT')['HRLYEARN'].sum().reset_index()
#                       LFSSTAT     HRLYEARN
# 0  Employed, absent from work   2143722.61
# 1           Employed, at work  20560876.43
# 2         Not in labour force         0.00
# 3                  Unemployed         0.00

# %%
df.groupby('IMMIG')['HRLYEARN'].mean().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_14720\2995266047.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('IMMIG')['HRLYEARN'].mean().reset_index()
#                                           IMMIG   HRLYEARN
# 0    Immigrant, landed 10 or less years earlier  29.880679
# 1  Immigrant, landed more than 10 years earlier  34.314263
# 2                                 Non-immigrant  32.984511

# %%
df.groupby(['EDUC','IMMIG'])['HRLYEARN'].mean().reset_index()

# %%
df.groupby(['EDUC','IMMIG'])['HRLYEARN'].mean().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_31164\2786644055.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['EDUC','IMMIG'])['HRLYEARN'].mean().reset_index()
#                                     EDUC  \
# 0                           0 to 8 years
# 1                           0 to 8 years
# 2                           0 to 8 years
# 3                Above bachelor's degree
# 4                Above bachelor's degree
# 5                Above bachelor's degree
# 6                      Bachelor's degree
# 7                      Bachelor's degree
# 8                      Bachelor's degree
# 9                   High school graduate
# 10                  High school graduate
# 11                  High school graduate
# 12  Postsecondary certificate or diploma
# ...

# %%
df.groupby(['EDUC','IMMIG'])['HRLYEARN'].mean().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_14720\2786644055.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['EDUC','IMMIG'])['HRLYEARN'].mean().reset_index()
#                                     EDUC  \
# 0                           0 to 8 years
# 1                           0 to 8 years
# 2                           0 to 8 years
# 3                Above bachelor's degree
# 4                Above bachelor's degree
# 5                Above bachelor's degree
# 6                      Bachelor's degree
# 7                      Bachelor's degree
# 8                      Bachelor's degree
# 9                   High school graduate
# 10                  High school graduate
# 11                  High school graduate
# 12  Postsecondary certificate or diploma
# ...

# %%
df.groupby(['NAICS_21','IMMIG'])['HRLYEARN'].mean().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_14164\845961328.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['NAICS_21','IMMIG'])['HRLYEARN'].mean().reset_index()
#                                              NAICS_21  \
# 0                     Accommodation and food services
# 1                     Accommodation and food services
# 2                     Accommodation and food services
# 3                                         Agriculture
# 4                                         Agriculture
# 5                                         Agriculture
# 6       Business, building and other support services
# 7       Business, building and other support services
# 8       Business, building and other support services
# 9                                        Construction
# ...

# %%
df.groupby(['IMMIG','LFSSTAT'])['HRLYEARN'].count().reset_index()
# Out:
# C:\Users\wmate\AppData\Local\Temp\ipykernel_35188\1254584417.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['IMMIG','LFSSTAT'])['HRLYEARN'].count().reset_index()
#                                            IMMIG                     LFSSTAT  \
# 0     Immigrant, landed 10 or less years earlier  Employed, absent from work
# 1     Immigrant, landed 10 or less years earlier           Employed, at work
# 2     Immigrant, landed 10 or less years earlier         Not in labour force
# 3     Immigrant, landed 10 or less years earlier                  Unemployed
# 4   Immigrant, landed more than 10 years earlier  Employed, absent from work
# 5   Immigrant, landed more than 10 years earlier           Employed, at work
# ...

# %%
df[["LFSSTAT",'EDUC','IMMIG']].value_counts().reset_index().sort_values(["LFSSTAT",'EDUC','IMMIG'])
# Out:
#                        LFSSTAT                                  EDUC  \
# 83  Employed, absent from work                          0 to 8 years
# 78  Employed, absent from work                          0 to 8 years
# 64  Employed, absent from work                          0 to 8 years
# 62  Employed, absent from work               Above bachelor's degree
# 58  Employed, absent from work               Above bachelor's degree
# 34  Employed, absent from work               Above bachelor's degree
# 54  Employed, absent from work                     Bachelor's degree
# 47  Employed, absent from work                     Bachelor's degree
# 24  Employed, absent from work                     Bachelor's degree
# 71  Employed, absent from work                  High school graduate
# 55  Employed, absent from work                  High school graduate
# 27  Employed, absent from work                  High school graduate
# 61  Employed, absent from work  Postsecondary certificate or diploma
# ...
